# %% [markdown]
# # Exploring Ebay Car Sales Data

# %% [markdown]
# ## Data Analysis and Visualization Course 1: Pandas and NumPy Fundamentals
# ### Guided Project to explore used cars datasets from Ebay using fundamentals of Pandas and Numpy Libraries

# %%
import pandas as pd
import numpy as np

# %%
autos = pd.read_csv('autos.csv', encoding='Latin-1')

# %%
autos.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# 0     150000                    0   benzin  volkswagen               NaN
# 1     125000                    5   diesel        audi                ja
# 2     125000                    8   diesel        jeep               NaN
# 3     150000                    6   benzin  volkswagen              nein
# 4      90000                    7   diesel       skoda              nein
#
#            dateCreated  nrOfPictures  postalCode             lastSeen
# 0  2016-03-24 00:00:00             0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00             0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00             0       90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00             0       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00             0       60437  2016-04-06 10:17:21

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
# dateCrawled            371528 non-null object
# name                   371528 non-null object
# seller                 371528 non-null object
# offerType              371528 non-null object
# price                  371528 non-null int64
# abtest                 371528 non-null object
# vehicleType            333659 non-null object
# yearOfRegistration     371528 non-null int64
# gearbox                351319 non-null object
# powerPS                371528 non-null int64
# model                  351044 non-null object
# kilometer              371528 non-null int64
# monthOfRegistration    371528 non-null int64
# fuelType               338142 non-null object
# brand                  371528 non-null object
# notRepairedDamage      299468 non-null object
# dateCreated            371528 non-null object
# nrOfPictures           371528 non-null int64
# postalCode             371528 non-null int64
# lastSeen               371528 non-null object
# dtypes: int64(7), object(13)
# memory usage: 56.7+ MB

# %% [markdown]
# ### Changing column names

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.columns=['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
       'vehicleType', 'registration_year', 'gearbox', 'powerPS', 'model',
       'kilometer', 'registration_month', 'fuelType', 'brand',
       'unrepaired_damage', 'ad_created', 'nrOfPictures', 'postalCode',
       'lastSeen']

# %%
autos.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  registration_year    gearbox  powerPS  model  \
# 0    480   test         NaN               1993    manuell        0   golf
# 1  18300   test       coupe               2011    manuell      190    NaN
# 2   9800   test         suv               2004  automatik      163  grand
# 3   1500   test  kleinwagen               2001    manuell       75   golf
# 4   3600   test  kleinwagen               2008    manuell       69  fabia
#
#    kilometer  registration_month fuelType       brand unrepaired_damage  \
# 0     150000                   0   benzin  volkswagen               NaN
# 1     125000                   5   diesel        audi                ja
# 2     125000                   8   diesel        jeep               NaN
# 3     150000                   6   benzin  volkswagen              nein
# 4      90000                   7   diesel       skoda              nein
#
#             ad_created  nrOfPictures  postalCode             lastSeen
# 0  2016-03-24 00:00:00             0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00             0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00             0       90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00             0       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00             0       60437  2016-04-06 10:17:21

# %%
autos.describe()
# Out:
#               price  registration_year        powerPS      kilometer  \
# count  3.715280e+05      371528.000000  371528.000000  371528.000000
# mean   1.729514e+04        2004.577997     115.549477  125618.688228
# std    3.587954e+06          92.866598     192.139578   40112.337051
# min    0.000000e+00        1000.000000       0.000000    5000.000000
# 25%    1.150000e+03        1999.000000      70.000000  125000.000000
# 50%    2.950000e+03        2003.000000     105.000000  150000.000000
# 75%    7.200000e+03        2008.000000     150.000000  150000.000000
# max    2.147484e+09        9999.000000   20000.000000  150000.000000
#
#        registration_month  nrOfPictures    postalCode
# count       371528.000000      371528.0  371528.00000
# mean             5.734445           0.0   50820.66764
# std              3.712412           0.0   25799.08247
# min              0.000000           0.0    1067.00000
# 25%              3.000000           0.0   30459.00000
# 50%              6.000000           0.0   49610.00000
# 75%              9.000000           0.0   71546.00000
# max             12.000000           0.0   99998.00000

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'registration_year', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'registration_month', 'fuelType', 'brand',
#        'unrepaired_damage', 'ad_created', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos['price'] = autos['price'].astype('int')
autos['kilometer'] = autos['kilometer'].astype('int')

# %%
autos['kilometer']
# Out:
# 0         150000
# 1         125000
# 2         125000
# 3         150000
# 4          90000
#            ...
# 371523     20000
# 371524    125000
# 371525    150000
# 371526    150000
# 371527     50000
# Name: kilometer, Length: 371528, dtype: int64

# %%
autos = autos.rename(columns={'kilometer':'odometer_km'})

# %%
autos['price'].unique().shape
# Out:
# (5597,)

# %%
autos.describe()
# Out:
#               price  registration_year        powerPS    odometer_km  \
# count  3.715280e+05      371528.000000  371528.000000  371528.000000
# mean   1.729514e+04        2004.577997     115.549477  125618.688228
# std    3.587954e+06          92.866598     192.139578   40112.337051
# min    0.000000e+00        1000.000000       0.000000    5000.000000
# 25%    1.150000e+03        1999.000000      70.000000  125000.000000
# 50%    2.950000e+03        2003.000000     105.000000  150000.000000
# 75%    7.200000e+03        2008.000000     150.000000  150000.000000
# max    2.147484e+09        9999.000000   20000.000000  150000.000000
#
#        registration_month  nrOfPictures    postalCode
# count       371528.000000      371528.0  371528.00000
# mean             5.734445           0.0   50820.66764
# std              3.712412           0.0   25799.08247
# min              0.000000           0.0    1067.00000
# 25%              3.000000           0.0   30459.00000
# 50%              6.000000           0.0   49610.00000
# 75%              9.000000           0.0   71546.00000
# max             12.000000           0.0   99998.00000

# %%
autos['price'].value_counts().sort_values(ascending=False)
# Out:
# 0        10778
# 500       5670
# 1500      5394
# 1000      4649
# 1200      4594
#          ...
# 51200        1
# 6170         1
# 4835         1
# 6370         1
# 8188         1
# Name: price, Length: 5597, dtype: int64

# %%
autos[autos['price'].between(1150,7200)]
# Out:
#                 dateCrawled                                           name  \
# 3       2016-03-17 16:54:04                             GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                 Skoda_Fabia_1.4_TDI_PD_Classic
# 6       2016-04-01 20:48:51                    Peugeot_206_CC_110_Platinum
# 10      2016-03-26 19:54:18                              Mazda_3_1.6_Sport
# 11      2016-04-07 10:06:22  Volkswagen_Passat_Variant_2.0_TDI_Comfortline
# ...                     ...                                            ...
# 371520  2016-03-19 19:53:49                                   turbo_defekt
# 371521  2016-03-27 20:36:20             Opel_Zafira_1.6_Elegance_TÜV_12/16
# 371523  2016-03-14 17:48:27                     Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21          Smart_smart_leistungssteigerung_100ps
# 371526  2016-03-20 19:41:08                         VW_Golf_Kombi_1_9l_TDI
#
#         seller offerType  price   abtest vehicleType  registration_year  \
# 3       privat   Angebot   1500     test  kleinwagen               2001
# 4       privat   Angebot   3600     test  kleinwagen               2008
# 6       privat   Angebot   2200     test      cabrio               2004
# 10      privat   Angebot   2000  control   limousine               2004
# 11      privat   Angebot   2799  control       kombi               2005
# ...        ...       ...    ...      ...         ...                ...
# 371520  privat   Angebot   3200  control   limousine               2004
# 371521  privat   Angebot   1150  control         bus               2000
# 371523  privat   Angebot   2200     test         NaN               2005
# 371524  privat   Angebot   1199     test      cabrio               2000
# 371526  privat   Angebot   3400     test       kombi               2002
#
#           gearbox  powerPS    model  odometer_km  registration_month fuelType  \
# 3         manuell       75     golf       150000                   6   benzin
# 4         manuell       69    fabia        90000                   7   diesel
# 6         manuell      109  2_reihe       150000                   8   benzin
# 10        manuell      105  3_reihe       150000                  12   benzin
# 11        manuell      140   passat       150000                  12   diesel
# ...           ...      ...      ...          ...                 ...      ...
# 371520    manuell      225     leon       150000                   5   benzin
# 371521    manuell        0   zafira       150000                   3   benzin
# 371523        NaN        0      NaN        20000                   1      NaN
# 371524  automatik      101   fortwo       125000                   3   benzin
# 371526    manuell      100     golf       150000                   6   diesel
#
#                  brand unrepaired_damage           ad_created  nrOfPictures  \
# 3           volkswagen              nein  2016-03-17 00:00:00             0
# 4                skoda              nein  2016-03-31 00:00:00             0
# 6              peugeot              nein  2016-04-01 00:00:00             0
# 10               mazda              nein  2016-03-26 00:00:00             0
# 11          volkswagen                ja  2016-04-07 00:00:00             0
# ...                ...               ...                  ...           ...
# 371520            seat                ja  2016-03-19 00:00:00             0
# 371521            opel              nein  2016-03-27 00:00:00             0
# 371523  sonstige_autos               NaN  2016-03-14 00:00:00             0
# 371524           smart              nein  2016-03-05 00:00:00             0
# 371526      volkswagen               NaN  2016-03-20 00:00:00             0
#
#         postalCode             lastSeen
# 3            91074  2016-03-17 17:40:17
# 4            60437  2016-04-06 10:17:21
# 6            67112  2016-04-05 18:18:39
# 10           96224  2016-04-06 10:45:34
# 11           57290  2016-04-07 10:25:17
# ...            ...                  ...
# 371520       96465  2016-03-19 20:44:43
# 371521       26624  2016-03-29 10:17:23
# 371523       39576  2016-04-06 00:46:52
# 371524       26135  2016-03-11 18:17:12
# 371526       40764  2016-03-24 12:45:21
#
# [186630 rows x 20 columns]

# %%
autos.drop(autos[autos['price']<100],axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-80bee9f115e3> in <module>
# ----> 1 autos.drop(autos[autos['price']<100],axis=0)
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# ~/anaconda3/envs/tf2/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['dateCrawled' 'name' 'seller' 'offerType' 'price' 'abtest' 'vehicleType'\n 'registration_year' 'gearbox' 'powerPS' 'model' 'odometer_km'\n 'registration_month' 'fuelType' 'brand' 'unrepaired_damage' 'ad_created'\n 'nrOfPictures' 'postalCode' 'lastSeen'] not found in axis"

# %%
autos[autos['price']<10]
# Out:
#                 dateCrawled  \
# 7       2016-03-21 18:54:38
# 40      2016-03-26 22:06:17
# 60      2016-03-29 15:48:15
# 91      2016-03-28 09:37:01
# 115     2016-03-19 18:40:12
# ...                     ...
# 371356  2016-03-09 15:56:30
# 371392  2016-03-20 14:55:07
# 371402  2016-03-24 13:48:05
# 371431  2016-03-10 22:55:50
# 371522  2016-03-21 09:50:58
#
#                                                      name  seller offerType  \
# 7                            VW_Derby_Bj_80__Scheunenfund  privat   Angebot
# 40                      Suche_Opel_corsa_a_zu_verschenken  privat   Angebot
# 60      TAUSCHE_BMW_E38_740i_g._SUV_/_GELÄNDEWAGEN_LES...  privat   Angebot
# 91      MERCEDES_BENZ_W124_250D_83KW_/_113PS___SCHLACH...  privat   Angebot
# 115                                       Golf_IV_1.4_16V  privat   Angebot
# ...                                                   ...     ...       ...
# 371356          Verkaufen_einen_Opel_corsa_b_worlcup_cool  privat   Angebot
# 371392   Ford_Fiesta_1.3___60PS___Bj_2002___Klima___Servo  privat   Angebot
# 371402                          Suzuki_Swift_zu_verkaufen  privat   Angebot
# 371431                                         Seat_Arosa  privat   Angebot
# 371522                                    Mitsubishi_Cold  privat   Angebot
#
#         price   abtest vehicleType  registration_year  gearbox  powerPS  \
# 7           0     test   limousine               1980  manuell       50
# 40          0     test         NaN               1990      NaN        0
# 60          1  control         suv               1994  manuell      286
# 91          1  control   limousine               1995  manuell      113
# 115         0     test         NaN               2017  manuell        0
# ...       ...      ...         ...                ...      ...      ...
# 371356      0  control         NaN               2000  manuell       65
# 371392      0     test  kleinwagen               2002  manuell       60
# 371402      0  control  kleinwagen               1999  manuell       53
# 371431      0  control  kleinwagen               1999  manuell       37
# 371522      0  control         NaN               2005  manuell        0
#
#            model  odometer_km  registration_month fuelType           brand  \
# 7         andere        40000                   7   benzin      volkswagen
# 40         corsa       150000                   1   benzin            opel
# 60           NaN       150000                  11      NaN  sonstige_autos
# 91      e_klasse       150000                   4   diesel   mercedes_benz
# 115         golf         5000                  12   benzin      volkswagen
# ...          ...          ...                 ...      ...             ...
# 371356     corsa       150000                   0      NaN            opel
# 371392    fiesta       150000                   3   benzin            ford
# 371402     swift       150000                   3   benzin          suzuki
# 371431     arosa       150000                   7   benzin            seat
# 371522      colt       150000                   7   benzin      mitsubishi
#
#        unrepaired_damage           ad_created  nrOfPictures  postalCode  \
# 7                   nein  2016-03-21 00:00:00             0       19348
# 40                   NaN  2016-03-26 00:00:00             0       56412
# 60                   NaN  2016-03-29 00:00:00             0       53721
# 91                  nein  2016-03-28 00:00:00             0       40589
# 115                  NaN  2016-03-19 00:00:00             0       21698
# ...                  ...                  ...           ...         ...
# 371356                ja  2016-03-09 00:00:00             0       23758
# 371392               NaN  2016-03-20 00:00:00             0       33659
# 371402               NaN  2016-03-24 00:00:00             0       42329
# 371431                ja  2016-03-10 00:00:00             0       22559
# 371522                ja  2016-03-21 00:00:00             0        2694
#
#                    lastSeen
# 7       2016-03-25 16:47:58
# 40      2016-03-27 17:43:34
# 60      2016-04-06 01:44:38
# 91      2016-04-06 12:15:54
# 115     2016-04-01 08:47:05
# ...                     ...
# 371356  2016-03-30 11:16:08
# 371392  2016-04-06 18:45:23
# 371402  2016-04-07 05:17:24
# 371431  2016-03-12 23:46:32
# 371522  2016-03-21 10:42:49
#
# [12034 rows x 20 columns]
