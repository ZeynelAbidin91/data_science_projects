# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
recent_grands = pd.read_csv('recent-grads.csv')

# %%
recent_grands.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grands.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  ...  \
# 168    Biology & Life Science    0.637293           47      6259  ...
# 169  Psychology & Social Work    0.817099            7      2125  ...
# 170  Psychology & Social Work    0.799859           13      2101  ...
# 171  Psychology & Social Work    0.798746           21      3777  ...
# 172                 Education    0.877960            2       742  ...
#
#      Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grands.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = recent_grands.shape[0]

# %%
recent_grands = recent_grands.dropna()

# %%
cleaned_data_counts = recent_grands.shape[0]

# %%
raw_data_count - cleaned_data_counts
# Out:
# 1

# %% [markdown]
# Only one data point had missing values and it was dropped.

# %%
recent_grands.plot(x='Sample_size', y='Median', kind='scatter', title='Sample_size vs. Median', figsize=(5,5))

# %%
recent_grands.plot(x='Sample_size', y='Unemployment_rate', kind='scatter', title='Sample_size vs. Unemployment_rate', figsize=(5,5))

# %%
recent_grands.plot(x='Full_time', y='Median', kind='scatter', title='Full_time vs. Median', figsize=(5,5))

# %%
recent_grands.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter', title='ShareWomen vs. Unemployment_rate', figsize=(5,5))

# %%
recent_grands.plot(x='Men', y='Women', kind='scatter', title='Men vs. Women', figsize=(5,5))

# %%
recent_grands.plot(x='Women', y='Median', kind='scatter', title='Women vs. Median', figsize=(5,5))

# %%
recent_grands['Sample_size'].plot(kind='hist')

# %%
recent_grands['Median'].plot(kind='hist')

# %%
recent_grands['Employed'].plot(kind='hist')

# %%
recent_grands['Full_time'].plot(kind='hist')

# %%
recent_grands['ShareWomen'].plot(kind='hist')

# %%
recent_grands['Unemployment_rate'].plot(kind='hist')

# %%
recent_grands['Men'].plot(kind='hist')

# %%
recent_grands['Women'].plot(kind='hist')

# %% [markdown]
# What percent of majors are predominantly male? Predominantly female?

# %%
recent_grands.groupby('Major').mean()['Women'].sort_values(ascending=False)
# Out:
# Major
# PSYCHOLOGY                                   307087.0
# NURSING                                      187621.0
# BIOLOGY                                      168947.0
# ELEMENTARY EDUCATION                         157833.0
# BUSINESS MANAGEMENT AND ADMINISTRATION       156118.0
#                                                ...
# NAVAL ARCHITECTURE AND MARINE ENGINEERING       135.0
# METALLURGICAL ENGINEERING                       131.0
# MATHEMATICS AND COMPUTER SCIENCE                109.0
# MINING AND MINERAL ENGINEERING                   77.0
# MILITARY TECHNOLOGIES                             0.0
# Name: Women, Length: 172, dtype: float64

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grands[['Median', 'Sample_size']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f46c12f0910>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grands[['Median', 'Sample_size', 'Unemployment_rate']], figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f46b7cc8a50>,
# ...
#       dtype=object)

# %%
recent_grands[:10]['ShareWomen'].plot(kind='bar')

# %%
recent_grands[-10:]['ShareWomen'].plot(kind='bar')

# %%
recent_grands[:10]['Unemployment_rate'].plot(kind='bar')

# %%
recent_grands[-10:]['Unemployment_rate'].plot(kind='bar')
